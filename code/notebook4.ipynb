# %% [markdown]
# # ***EABL STOCK PERFORMANCE ANALYSIS WITH TIME SERIES AND SENTIMENT DATA***

# %% [markdown]
# # ***1.BUSINESS UNDERSTANDING***

# %% [markdown]
# **PROBLEM STATEMENT:**
#
# •	EABL, a leading East African brewery company, has been experiencing stock price volatility and stagnation over the past 10 years, impacting shareholder confidence and investment stability.
#
# •	Recent regulatory actions, such as the Kenya Revenue Authority's imposition of a policy requiring EABL to file returns within 24 hours, further exacerbate challenges faced by the company.
#
# •	The primary challenge is to devise data-driven strategies to stabilize EABL's stock performance, mitigate the impact of regulatory policies, and foster exponential growth in shareholder value.
#
# **BUSINESS OBJECTIVES:**
#
# •	Maintain investor confidence and prevent shareholder withdrawal amidst stock price volatility and regulatory pressures.
#
# •	Stabilize EABL's stock performance and foster sustainable growth in stock value over time.
#
# •	Enhance EABL's resilience to regulatory changes and policy disruptions while optimizing financial outcomes.
#
# **CONTEXT:**
#
# •	EABL operates in the highly competitive and dynamic East African brewery industry, facing challenges such as changing consumer preferences, regulatory scrutiny, and economic fluctuations.
#
# •	The company's success is closely tied to its brand reputation, product quality, market positioning, and ability to adapt to evolving market conditions.
#
# •	Regulatory interventions, such as the Kenya Revenue Authority's policy, can significantly impact EABL's operational efficiency, financial reporting processes, and investor perception.

# %% [markdown]
# # ***PROJECT PLAN***
#
# To address the challenge faced by EABL, a data-driven solution leveraging product sentiment analysis and time series data can be formulated
#
# ## ***Data Collection and Preprocessing:***
#
# •	Gather historical stock market data for EABL, including daily closing prices, trading volume, and any relevant financial indicators.
#
# •	Acquire sentiment data related to EABL's products from social media, customer reviews, and other relevant sources. Utilize natural language processing (NLP) techniques to extract sentiment scores.
#
# •	Organize and preprocess the collected data to ensure consistency and accuracy for analysis.
#
# ## ***Time Series Analysis:***
#
# •	Conduct time series analysis on EABL's stock performance to identify patterns, trends, and factors influencing stock fluctuations over the past 18 years.
#
# •	Use statistical methods such as trend analysis, and seasonal decomposition to understand the underlying dynamics of the stock market behavior.
#
# ## ***Sentiment Analysis:***
#
# •	Perform sentiment analysis on product-related data to gauge customer perception, satisfaction, and sentiment towards EABL's offerings.
#
# •	Classify sentiments into positive, negative, or neutral categories and quantify the intensity of sentiment shifts over time.
#
# ## ***Correlation Analysis:***
#
# •	Explore the relationship between product sentiment scores and stock market performance using statistical techniques.
#
# •	Identify correlations and causal relationships between changes in sentiment and fluctuations in stock prices.
#
# ## ***Predictive Modeling:***
#
# •	Develop predictive models using machine learning algorithms such as time series forecasting, or sentiment-based models.
#
# •	Predict future stock price movements based on historical trends, sentiment analysis results, and other relevant factors.
#
# ## ***Recommendations and Strategies:***
#
# •	Generate actionable insights and recommendations for EABL's stakeholders based on data-driven analysis.
#
# •	Propose strategies to mitigate the negative effects of stock tanking and regulatory challenges.
#
# •	Suggest proactive measures to enhance product quality, customer satisfaction, and brand reputation to stabilize and grow the company's stock value.
#
# ## ***Continuous Monitoring and Adaptation:***
#
# •	Establish a framework for ongoing monitoring of stock market trends, sentiment dynamics, and policy developments.
#
# •	Continuously refine and adapt the data-driven solution based on real-time data updates and feedback from stakeholders.

# %% [markdown]
# ---------------------------------------------------------
# # ***2.DATA UNDERSTANDING AND  ANALYSIS***

# %% [markdown]
# # ***2.1.TIME SERIES ANALYSIS***

# %% [markdown]
# ***Volatility Analysis:***
#
# Objective: Quantify EABL's stock volatility to assess investment risk. Develop a risk model to identify and quantify potential risks, providing investors with a comprehensive risk assessment tool.
#
# ***Analysis of Abnormal Trade Volume:***
#
# Objective: Investigate anomalies in trade volumes, such as spikes or drops, to understand their causes and implications for market dynamics.
#
# ***Dividends Analysis:***
#
# Objective: Evaluate EABL's dividend payout trends to inform investment decisions.
#
# ***Trend and Seasonality Analysis:***
#
# Objective: Identify and analyze trends, seasonal patterns, and autocorrelations in EABL's stock data to forecast future movements.
#
# ***Lag Analysis with Market Indicators:***
#
# Objective: Examine the impact of external market indicators (e.g., inflation rates, GDP, USD exchange rates, unemployment rates) on EABL's stock performance.
#
# ***Stock Valuation:***
#
# Objective: Determine the intrinsic value of EABL stocks to assess their investment potential.

# %%
# Let's start by loading the uploaded CSV file to understand its structure and perform some initial data cleaning.

import pandas as pd

# Load the data
file_path =  r"C:\Users\ADMIN\OneDrive\Desktop\DEREK\dsc-capstone-project_finale\data\processed\merge_sentiments_final.csv"
data = pd.read_csv(file_path)

# Display the first few rows of the dataset to understand its structure
data
# Out:
#       Unnamed: 0        Date   Open   High    Low  Close  Average  Volume  \
# 0              0  2024-01-31  104.0  111.0  104.0  110.0    106.0   42000
# 1              1  2024-01-30  105.0  105.0  101.0  104.0    104.0   15600
# 2              1  2024-01-30  105.0  105.0  101.0  104.0    104.0   15600
# 3              1  2024-01-30  105.0  105.0  101.0  104.0    104.0   15600
# 4              1  2024-01-30  105.0  105.0  101.0  104.0    104.0   15600
# ...          ...         ...    ...    ...    ...    ...      ...     ...
# 4950        4348  2006-09-15  141.0  142.0  140.0  141.0    141.0  226100
# 4951        4349  2006-09-14  140.0  143.0  140.0  140.0    141.0  108500
# 4952        4350  2006-09-13  141.0  144.0  140.0  142.0    141.0  190000
# 4953        4351  2006-09-12  141.0  143.0  140.0  140.0    140.0  123900
# 4954        4352  2006-09-11  135.0  144.0  135.0  143.0    140.0   30500
#
#       Month  Year  ...  12-Month Inflation      Mean  Amount  \
# 0         1  2024  ...                6.90  161.0000    1.00
# 1         1  2024  ...                6.90  161.0000    1.00
# 2         1  2024  ...                6.90  161.0000    1.00
# 3         1  2024  ...                6.90  161.0000    1.00
# 4         1  2024  ...                6.90  161.0000    1.00
# ...     ...   ...  ...                 ...       ...     ...
# 4950      9  2006  ...                5.93   73.3144    4.15
# 4951      9  2006  ...                5.93   73.3178    4.15
# 4952      9  2006  ...                5.93   73.2778    4.15
# 4953      9  2006  ...                5.93   72.8644    4.15
# 4954      9  2006  ...                5.93   72.7744    4.15
#
#       Dividends per share  Earnings Per Share  Unemployment  Interest rates  \
# 0                     NaN                 NaN          3.70            12.5
# 1                     NaN                 NaN          3.70            12.5
# 2                     NaN                 NaN          3.70            12.5
# 3                     NaN                 NaN          3.70            12.5
# 4                     NaN                 NaN          3.70            12.5
# ...                   ...                 ...           ...             ...
# 4950                  5.9                 8.3          2.92            10.0
# 4951                  5.9                 8.3          2.92            10.0
# 4952                  5.9                 8.3          2.92            10.0
# 4953                  5.9                 8.3          2.92            10.0
# 4954                  5.9                 8.3          2.92            10.0
#
#                                                    text  No_of_likes  \
# 0     Heritage Foundation Project2025 Will dismantle...         25.0
# 1     Going to EABL Liqour Shop to buy all the Guinn...          4.0
# 2     EABL snapped back today and ended the day 4% u...         17.0
# 3                  EABL won't collapse under my watch .       1995.0
# 4     Wacha ninunue chrome kadhaa EABL wapate pesa z...         27.0
# ...                                                 ...          ...
# 4950                                                NaN          NaN
# 4951                                                NaN          NaN
# 4952                                                NaN          NaN
# 4953                                                NaN          NaN
# 4954                                                NaN          NaN
#
#      No_of_tweets
# 0             5.0
# 1             0.0
# 2             0.0
# 3            13.0
# 4             3.0
# ...           ...
# 4950          NaN
# 4951          NaN
# 4952          NaN
# 4953          NaN
# 4954          NaN
#
# [4955 rows x 22 columns]

# %%
# Columns to drop
columns_to_drop = ['text', 'No_of_likes', 'No_of_tweets', 'Unnamed: 0']

# Dropping columns
data = data.drop(columns=columns_to_drop)

data
# Out:
#             Date   Open   High    Low  Close  Average  Volume  Month  Year  \
# 0     2024-01-31  104.0  111.0  104.0  110.0    106.0   42000      1  2024
# 1     2024-01-30  105.0  105.0  101.0  104.0    104.0   15600      1  2024
# 2     2024-01-30  105.0  105.0  101.0  104.0    104.0   15600      1  2024
# 3     2024-01-30  105.0  105.0  101.0  104.0    104.0   15600      1  2024
# 4     2024-01-30  105.0  105.0  101.0  104.0    104.0   15600      1  2024
# ...          ...    ...    ...    ...    ...      ...     ...    ...   ...
# 4950  2006-09-15  141.0  142.0  140.0  141.0    141.0  226100      9  2006
# 4951  2006-09-14  140.0  143.0  140.0  140.0    141.0  108500      9  2006
# 4952  2006-09-13  141.0  144.0  140.0  142.0    141.0  190000      9  2006
# 4953  2006-09-12  141.0  143.0  140.0  140.0    140.0  123900      9  2006
# 4954  2006-09-11  135.0  144.0  135.0  143.0    140.0   30500      9  2006
#
#       Day  Annual Average Inflation  12-Month Inflation      Mean  Amount  \
# 0      31                       NaN                6.90  161.0000    1.00
# 1      30                       NaN                6.90  161.0000    1.00
# 2      30                       NaN                6.90  161.0000    1.00
# 3      30                       NaN                6.90  161.0000    1.00
# 4      30                       NaN                6.90  161.0000    1.00
# ...   ...                       ...                 ...       ...     ...
# 4950   15                       5.7                5.93   73.3144    4.15
# 4951   14                       5.7                5.93   73.3178    4.15
# 4952   13                       5.7                5.93   73.2778    4.15
# 4953   12                       5.7                5.93   72.8644    4.15
# 4954   11                       5.7                5.93   72.7744    4.15
#
#       Dividends per share  Earnings Per Share  Unemployment  Interest rates
# 0                     NaN                 NaN          3.70            12.5
# 1                     NaN                 NaN          3.70            12.5
# 2                     NaN                 NaN          3.70            12.5
# 3                     NaN                 NaN          3.70            12.5
# 4                     NaN                 NaN          3.70            12.5
# ...                   ...                 ...           ...             ...
# 4950                  5.9                 8.3          2.92            10.0
# 4951                  5.9                 8.3          2.92            10.0
# 4952                  5.9                 8.3          2.92            10.0
# 4953                  5.9                 8.3          2.92            10.0
# 4954                  5.9                 8.3          2.92            10.0
#
# [4955 rows x 18 columns]

# %% [markdown]
# The dataset contains 4,955 entries with 18 columns, detailing EABL's stock performance and related economic indicatorse and broader market factors over a 18 year period, ending most recently on January 31, 2024. Here's a summary of the columns present in the dataset:
#
# - ***Date:** The date of the record, indicating when the stock information was recorded.
#
# - ***Open, High, Low, Close:*** Stock prices at the open, highest price, lowest price, and close of the trading day, respectively.
#
# - ***Average:*** The average price of the stock for the day.
#
# - ***Volume:*** The number of shares traded during the day.
#
# - ***Month, Year, Day:*** Broken down components of the date for easy access to month, year, and day.
#
# - ***Annual Average Inflation:*** Possibly an indicator meant to show inflation rates, though it seems to have missing values for the recent entries.
#
# - ***12-Month Inflation:*** Inflation rate over the past 12 months.
#
# - ***Mean:*** Exchange rates economic indicator.
#
# - ***Amount:*** Could be related to dividend amounts, though clarification is needed.
#
# - ***Dividends per share:*** The amount of dividend paid per share.
#
# - ***Earnings Per Share:*** Profit per share over a specified period, though it appears to have missing values in the latest entries.
#
# - ***Unemployment:*** The unemployment rate.
#
# - ***Interest Rates:*** The CBK interest rates
#
# Before proceeding with the analysis, we should perform some standard data cleaning steps, including:
#
# - ***Dropping the Annual Average Inflation***, as it appears to be an unnecessary column.
#
# - ***Parsing the Date column into a datetime format for time series analysis.***
#
# - Checking for and handling any missing values, especially in key columns like Earnings Per Share.
#
# - Ensuring numerical columns are of the correct data type for analysis.

# %%
# Drop the 'Annual Average Inflation' column

data_cleaned = data.drop(columns=['Annual Average Inflation'])

# Convert 'Date' column to datetime format
data_cleaned['Date'] = pd.to_datetime(data_cleaned['Date'])

# Check data types and look for missing values
data_types = data_cleaned.dtypes
missing_values = data_cleaned.isnull().sum()

# Display data types and missing values information
data_types
# Out:
# Date                   datetime64[ns]
# Open                          float64
# High                          float64
# Low                           float64
# Close                         float64
# Average                       float64
# Volume                          int64
# Month                           int64
# Year                            int64
# Day                             int64
# 12-Month Inflation            float64
# Mean                          float64
# Amount                        float64
# Dividends per share           float64
# Earnings Per Share            float64
# Unemployment                  float64
# Interest rates                float64
# dtype: object

# %%
missing_values
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Close                   0
# Average                 0
# Volume                  0
# Month                   0
# Year                    0
# Day                     0
# 12-Month Inflation      0
# Mean                    4
# Amount                  0
# Dividends per share    40
# Earnings Per Share     41
# Unemployment            0
# Interest rates          0
# dtype: int64

# %% [markdown]
# We have identified missing values in the following columns:
#
# - Dividends Per Share with 40 missing values
#
# - Earnings Per Share each have 41 missing values.
#
# - Mean has 4 missing values.
#
# For Earnings Per Share, missing values will be imputed due to  their significance to the analysis.
#
# The Dividends Per Share  will be filled using backward fill
#
# The "mean" column will be filled with interpolated values.

# %%
# Impute missing values for 'Earnings Per Share' with the column's mean
eps_mean = data_cleaned['Earnings Per Share'].mean()
data_cleaned['Earnings Per Share'].fillna(eps_mean, inplace=True)

# Use linear interpolation to fill missing values for'Mean' and backward fill forDividends Per Share
data_cleaned['Dividends per share'] = data_cleaned['Dividends per share'].fillna(method='bfill')
data_cleaned['Mean'].interpolate(method='linear', inplace=True)

# Verify that missing values have been addressed
missing_values_after_imputation = data_cleaned.isnull().sum()

missing_values_after_imputation
# Out:
# Date                   0
# Open                   0
# High                   0
# Low                    0
# Close                  0
# Average                0
# Volume                 0
# Month                  0
# Year                   0
# Day                    0
# 12-Month Inflation     0
# Mean                   0
# Amount                 0
# Dividends per share    0
# Earnings Per Share     0
# Unemployment           0
# Interest rates         0
# dtype: int64

# %% [markdown]
# # ***Volatility Analysis***

# %% [markdown]
# Volatility is a statistical measure of the dispersion of returns for a given security or market index. In most cases, the higher the volatility, the riskier the security. We'll calculate the historical volatility of EABL's stock, using the standard deviation of daily returns as a proxy for volatility.
#
# For this purpose, we need to:
#
# - Calculate the daily returns of EABL's stock.
# - Define and implement a method to calculate the rolling standard deviation of these returns, which represents the volatility.
# - Visualize the volatility over time to identify any patterns or trends.

# %%
import numpy as np
import matplotlib.pyplot as plt

class StockVolatility:
    def __init__(self, data):
        self.data = data
        self.returns = None
    
    def calculate_returns(self):
        """Calculate daily returns from the Close prices."""
        self.data['Returns'] = self.data['Close'].pct_change()
        self.returns = self.data['Returns']
    
    def calculate_volatility(self):
        """Calculate the annualized volatility of the stock."""
        daily_volatility = self.returns.std()
        annualized_volatility = daily_volatility * np.sqrt(252)  # Assuming 252 trading days in a year
        return annualized_volatility
    
    def plot_volatility(self):
        """Plot the rolling 30-day volatility of the stock."""
        rolling_volatility = self.returns.rolling(window=30).std() * np.sqrt(252)
        plt.figure(figsize=(10, 6))
        rolling_volatility.plot()
        plt.title('30-Day Rolling Volatility of EABL Stock')
        plt.xlabel('Date')
        plt.ylabel('Annualized Volatility')
        plt.show()

# Instantiate the StockVolatility class and perform the analysis
eabl_volatility = StockVolatility(data_cleaned)
eabl_volatility.calculate_returns()

# Calculate and display the annualized volatility
annualized_volatility = eabl_volatility.calculate_volatility()
print(f"Annualized Volatility: {annualized_volatility:.2%}")

# Plot the 30-day rolling volatility
eabl_volatility.plot_volatility()
# Out:
# Annualized Volatility: 32.65%

# %% [markdown]
# ## ***Observation:***
#
# The average volatility rate for EABL's stock over the period analyzed is approximately 32.65%. This rate indicates the average level of fluctuation in the stock's daily returns on an annualized basis, reflecting the stock's risk profile. A volatility rate of this magnitude suggests that EABL's stock has experienced moderate to high levels of price fluctuations, which is a crucial factor for investors to consider in their risk assessment and investment strategy. ​​
#
# ## ***Insights:***
#
# - ***For Risk-Averse Investors:*** Given the relatively high volatility of EABL's stock, more cautious investors might prefer to look for lower-volatility investment opportunities unless they are comfortable with the associated risk levels.
#
# - ***For Risk-Tolerant Investors:*** Those willing to accept higher volatility in exchange for the potential of significant gains might find EABL's stock to be an attractive option. However, it is crucial to implement robust risk management strategies, such as diversification and setting stop-loss orders.
#
# - ***Market Timing:*** Investors might also use volatility trends to time their market entry and exit. Periods of increasing volatility could signal opportunities for high returns, but they should be approached with caution and a clear understanding of potential downside risks.
#
#
# The analysis of EABL's stock volatility reveals a substantial level of risk, characterized by the potential for significant price fluctuations. Investors should consider their risk tolerance and investment horizon when deciding to invest in EABL stocks. By understanding and planning for volatility, investors can better position themselves to navigate the uncertainties of the stock market and capitalize on potential opportunities. ​

# %% [markdown]
# # ***Abnormal Trade Volume Analysis:***

# %% [markdown]
# - We'll focus on identifying and understanding instances where EABL's trading volume significantly deviates from its typical levels. Such spikes can indicate a variety of market conditions or events, such as new product launches, earnings reports, changes in management, or broader economic news impacting the stock.
#
# - Detecting these spikes can provide valuable insights into potential market sentiment changes or upcoming volatility
#
# - We'll use a z-score approach to identify outliers in trading volumes. The z-score measures the number of standard deviations an element is from the mean. Typically, a z-score above 2 or below -2 is considered abnormal.

# %%
class TradeVolumeAnalysis:
    def __init__(self, data):
        self.data = data
    
    def detect_spikes(self, threshold=2):
        """Identify days with abnormal trade volume spikes.
        
        Args:
            threshold (float): The number of standard deviations from the mean to consider a spike.
        
        Returns:
            DataFrame: A subset of the original DataFrame with only the days of abnormal volume spikes.
        """
        self.data['Volume_Mean'] = self.data['Volume'].rolling(window=30).mean()
        self.data['Volume_Std'] = self.data['Volume'].rolling(window=30).std()
        self.data['Z_Score'] = (self.data['Volume'] - self.data['Volume_Mean']) / self.data['Volume_Std']
        
        # Filter rows where the Z-score is above the threshold
        spikes = self.data[self.data['Z_Score'] > threshold]
        return spikes
    
    def plot_volume_spikes(self):
        """Plot the daily trade volume with highlights on days of abnormal spikes."""
        plt.figure(figsize=(20, 8))
        plt.plot(self.data['Date'], self.data['Volume'], label='Daily Volume')
        
        # Detect spikes
        spikes = self.detect_spikes()
        
        plt.scatter(spikes['Date'], spikes['Volume'], color='red', label='Volume Spikes')
        plt.title('EABL Trade Volume with Abnormal Spikes Highlighted')
        plt.xlabel('Date')
        plt.ylabel('Trade Volume')
        plt.legend()
        plt.show()

        return spikes

# Instantiate the TradeVolumeAnalysis class and perform the analysis
volume_analysis = TradeVolumeAnalysis(data_cleaned)
spikes_df = volume_analysis.plot_volume_spikes()

# Display the dates and volumes of detected spikes for review
spikes_df[['Date', 'Volume', 'Z_Score']]
# Out:
#            Date   Volume   Z_Score
# 79   2023-12-21   305500  5.294610
# 91   2023-12-07   264300  3.307518
# 92   2023-12-07   264300  2.734031
# 93   2023-12-07   264300  2.360544
# 158  2023-10-11   283900  5.272459
# ...         ...      ...       ...
# 4909 2006-11-16   480300  2.563505
# 4921 2006-10-31   433800  2.375978
# 4923 2006-10-27   464500  2.273895
# 4931 2006-10-13  1145100  4.094252
# 4938 2006-10-03  1106300  3.126702
#
# [315 rows x 3 columns]

# %% [markdown]
# By calculating the z-score for each day's trading volume and flagging those with scores exceeding a threshold of 2, we pinpointed days with significantly higher than average trading activity.
#
# ## ***Examples of Detected Abnormal Volumes:***
# - December 21, 2023: Volume of 305,500 with a z-score of 5.29.
# - October 11, 2023: Volume of 283,900 with a z-score of 5.27
# - November 16, 2006: Volume of 480,300 with a z-score of 2.56.
# - October 31 2006: Volume of 433,800 with a z-score of 2.37
#
# ## ***Observations***
# - ***Significance of Spikes:*** The days highlighted with red in the plot indicate significant deviations in trading volume, suggesting notable events or news impacting investor sentiment and actions.
#
# - ***Potential Causes:*** These spikes could be attributed to various factors such as earnings announcements, strategic corporate decisions, regulatory news, or market rumors. Further investigation into the specific dates could provide context to these volume spikes, offering deeper insights into their causes and implications.
#
# - ***Investment Strategy Considerations:*** Abnormal volume spikes can serve as a precursor to price movements. An increase in volume often precedes price volatility, suggesting that the stock could be on the verge of a breakout or breakdown.
#
# ## ***Rationale:***
# Trade volume spikes can result from a variety of causes, including but not limited to:
#
# - ***Corporate news or events:*** Announcements related to earnings, mergers, acquisitions, or other significant corporate events.
#
# - ***Market sentiment:*** Changes in investor sentiment due to broader market or economic news.
#
# - ***Institutional trading activity:*** Large trades executed by institutional investors or hedge funds.
#
# ## ***Insights:***
#
# - ***Market Surveillance:** Investors and analysts should closely monitor news and events around the dates of these volume spikes to understand the underlying causes and potential market reactions.
#
# - **Investment Strategy:*** Abnormal volume days can sometimes precede significant price movements. Investors might use this information to adjust their investment strategies, potentially taking positions before expected moves or using the information to time exits.
#
# - ***Risk Assessment:*** Sudden increases in trade volume, especially when not accompanied by significant news, might indicate speculative trading or manipulation. Investors should be cautious and conduct thorough research before making investment decisions based on volume spikes alone.

# %% [markdown]
# # ***Dividends Analysis***

# %% [markdown]
# For the Dividends Analysis, we'll focus on understanding the trends and patterns in East African Breweries Limited (EABL)'s dividend payouts. Dividends are a critical component for investors, especially those seeking income from their investments. Analyzing the dividend history can provide insights into the company's profitability, stability, and management's confidence in future earnings.

# %%
class DividendsAnalysis:
    """
    A class for analyzing dividend payout trends.
    """
    def __init__(self, data):
        self.data = data
        # Ensure there's a 'Year' column for annual analysis
        if 'Year' not in self.data.columns:
            self.data['Date'] = pd.to_datetime(self.data['Date'])
            self.data['Year'] = self.data['Date'].dt.year
        self.dividend_data = self.data[['Year', 'Dividends per share']].drop_duplicates().dropna()
        
    def calculate_dividend_growth(self):
        """
        Calculate the year-over-year growth rate of dividends per share.
        """
        self.dividend_data['Growth'] = self.dividend_data['Dividends per share'].pct_change() * 100
        return self.dividend_data
    
    def plot_dividend_trends(self):
        """
        Visualize the trends in dividend payouts over time, including growth rates.
        """
        fig, ax1 = plt.subplots(figsize=(14, 7))

        color = 'tab:red'
        ax1.set_xlabel('Year')
        ax1.set_ylabel('Dividends per Share', color=color)
        ax1.plot(self.dividend_data['Year'], self.dividend_data['Dividends per share'], color=color, label='Dividends per Share')
        ax1.tick_params(axis='y', labelcolor=color)
        
        ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
        color = 'tab:blue'
        ax2.set_ylabel('Growth Rate (%)', color=color)  # we already handled the x-label with ax1
        ax2.plot(self.dividend_data['Year'], self.dividend_data['Growth'], color=color, label='Growth Rate')
        ax2.tick_params(axis='y', labelcolor=color)
        
        fig.tight_layout()  # otherwise the right y-label is slightly clipped
        plt.title('EABL Dividends per Share and Growth Rate Over Time')
        plt.show()

# Initialize the class with the cleaned data (assuming data_cleaned is the dataset to use)
dividends_analysis = DividendsAnalysis(data_cleaned)

# Calculate dividend growth rates
dividend_growth_data = dividends_analysis.calculate_dividend_growth()

# Plotting dividend trends and growth rates
dividends_analysis.plot_dividend_trends()

# Displaying the calculated growth rates for review
dividend_growth_data[['Year', 'Dividends per share', 'Growth']]
# Out:
#       Year  Dividends per share      Growth
# 0     2024                 5.50         NaN
# 41    2023                 5.50    0.000000
# 550   2022                11.00  100.000000
# 855   2021                 5.50  -50.000000
# 1138  2020                 3.00  -45.454545
# 1446  2019                 8.50  183.333333
# 1765  2018                 7.50  -11.764706
# 2018  2017                 7.50    0.000000
# 2266  2016                12.00   60.000000
# 2514  2015                 7.50  -37.500000
# 2828  2014                 5.50  -26.666667
# 3080  2013                 5.50    0.000000
# 3376  2012                 8.75   59.090909
# 3629  2011                 8.75    0.000000
# 3879  2010                 8.75    0.000000
# 4132  2009                 8.05   -8.000000
# 4382  2008                 8.05    0.000000
# 4633  2007                 7.70   -4.347826
# 4881  2006                 5.90  -23.376623

# %% [markdown]
# ## ***Observation:***
# The analysis reveals fluctuating trends in EABL's dividends per share over the recent years, with significant growth seen in 2022 followed by a drop in 2023, and stabilization in 2024. Notably, there's an apparent discrepancy in 2024 with two entries, one indicating a continuation of the previous dividend rate (5.5) and another showing a drop to 0.0, which suggests a discontinuation or a special case affecting dividend payout.
#
# ## ***Rationale:***
#
# - ***Growth in 2022:*** The doubling of dividends in 2022 could indicate strong financial performance or a strategic decision to return more capital to shareholders.
#
# - ***Drop in 2023:*** The subsequent drop might reflect adjustments in financial strategy, a reallocation of profits towards growth investments, or a response to external economic pressures.
#
# - ***Situation in 2024:*** The mixed signals in 2024 require further investigation. The record showing a dividend of 0 could be due to an error, a temporary suspension of dividends, or a placeholder until final decisions are made.
#
# ## ***Insights:***
#
# - ***Investment Consideration:*** Investors should closely monitor EABL's financial reports and shareholder communications for insights into dividend policies and sustainability. The historical volatility in dividends suggests a need for caution, especially for those relying on dividend income.
#
# - ***Long-Term Strategy:*** Given the fluctuations, a long-term perspective is advisable when incorporating EABL stocks into a portfolio. Consider the overall yield and the potential for capital appreciation.
#
# - ***Further Research:*** The anomaly in 2024 warrants further investigation. Investors should seek additional information regarding the company's dividend policy and future outlook to understand the potential impact on investment returns.

# %% [markdown]
# # ***Trend Analysis***

# %% [markdown]
# For the Trend Analysis of East African Breweries Limited (EABL)'s stock, we will examine the historical price data to identify any prevailing trends, seasonal patterns, and any potential autocorrelation in the stock prices over time. Understanding these aspects can help in forecasting future price movements and in making informed investment decisions.
#
# To conduct this analysis, we will use the TrendAnalysis class with methods for:
#
# - ***Trend Detection:*** Identify long-term movements in the stock prices.
# - ***Seasonality Analysis:*** Examine the data for regular, repeating patterns that occur over a known period.
# - ***Autocorrelation Analysis:*** Determine if the stock prices are correlated with their past values, which can be useful for predictive modeling.

# %%
# Importing necessary libraries for trend analysis
from statsmodels.tsa.seasonal import seasonal_decompose
from pandas.plotting import autocorrelation_plot

class TrendAnalysis:
    """
    A class to perform trend analysis on stock prices.
    """
    def __init__(self, data):
        self.data = data.copy()
        self.data['Date'] = pd.to_datetime(self.data['Date'])
        self.data.set_index('Date', inplace=True)
        
    def decompose_series(self, model='additive'):
        """
        Decompose the time series into its trend, seasonal, and residual components.
        """
        # Assuming 'Close' price for analysis and a frequency of 252 trading days per year
        decomposition = seasonal_decompose(self.data['Close'], model=model, period=252)
        return decomposition
    
    def plot_decomposition(self, decomposition):
        """
        Plot the decomposed components of the time series.
        """
        fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(14, 10))
        decomposition.observed.plot(ax=ax1)
        ax1.set_title('Observed')
        decomposition.trend.plot(ax=ax2)
        ax2.set_title('Trend')
        decomposition.seasonal.plot(ax=ax3)
        ax3.set_title('Seasonal')
        decomposition.resid.plot(ax=ax4)
        ax4.set_title('Residual')
        plt.tight_layout()
    
    def plot_autocorrelation(self):
        """
        Plot the autocorrelation of the 'Close' price to identify any autocorrelation patterns.
        """
        plt.figure(figsize=(14, 7))
        autocorrelation_plot(self.data['Close'])
        plt.title('Autocorrelation of EABL Closing Prices')
        plt.show()

# Initialize the class with the cleaned data
trend_analysis = TrendAnalysis(data_cleaned)

# Decompose the series
decomposition = trend_analysis.decompose_series()

# Plotting the decomposition
trend_analysis.plot_decomposition(decomposition)

# Plotting the autocorrelation
trend_analysis.plot_autocorrelation()

# %% [markdown]
# ### ***Decomposition Analysis:***
# - ***Observed:*** The observed data shows fluctuations over the years with a noticeable decline in values after 2013.
#
# - ***Trend:*** There is a clear upward trend until around 2013, after which there is a decline. This suggests EABL's stock had been increasing over time but has started to decrease recently.
#
# - ***Seasonal:*** The seasonal component reveals any repeating patterns or cycles in the stock prices over a specified period. In this case, the analysis aimed to uncover any monthly or quarterly patterns, but the visualization suggests that seasonality may not be a dominant feature in EABL's stock price movements.
#
# - ***Residual:*** Residuals are relatively stable with some spikes indicating instances where the price significantly deviated from the trend and seasonal components.
#
# ### ***Autocorrelation Analysis:***
# - The autocorrelation plot indicates how the stock's closing prices correlate with its past values. Peaks in the plot suggest that the stock prices have some degree of predictability based on their past values. In this case, the autocorrelation plot shows a gradual decline, suggesting that past prices have some influence on future prices, but this influence diminishes over time.
#
# ### ***Observations:***
# - ***Trend Identification:*** Understanding the long-term trend is crucial for making investment decisions, especially for buy-and-hold investors. The trend analysis suggests a direction that the stock might continue to follow.
#
# - ***Seasonality Insights:*** While the analysis does not strongly indicate significant seasonality in EABL's stock prices, investors should still consider other cyclical factors that might affect the stock market in general.
#
# - ***Predictive Modeling:*** The autocorrelation analysis provides a basis for developing predictive models. Stocks with significant autocorrelation can often be forecasted more accurately using past price data.
#
# ### ***Insights:***
# - ***Long-Term Investments:*** Investors looking for long-term opportunities should pay close attention to the trend component to align their investment strategies with the overall direction of the stock.
#
# - ***Trading Strategies:*** Traders might use autocorrelation insights to develop short-term trading strategies, capitalizing on the predictability of price movements.
#
# - ***Diversification:*** The absence of strong seasonality suggests that EABL's stock might not offer diversification benefits based on seasonal trading strategies alone. Investors might need to look for other stocks or assets with clearer seasonal patterns for diversification purposes.
#
# Investigate the causes of the decline post-2013 and develop strategies to mitigate or reverse this trend.

# %% [markdown]
# # ***Lag Analysis***

# %% [markdown]
# For the Lag Analysis, we'll examine how various market indicators, specifically inflation rates, GDP, USD exchange rates, and unemployment rates, impact East African Breweries Limited (EABL)'s stock prices. Understanding these relationships can provide insights into how external economic factors influence stock performance, which is essential for making informed investment decisions.
#
# To conduct this analysis, we will enhance the LagAnalysis class to include methods for:
#
# - ***Correlation Analysis:*** To identify the strength and direction of the relationship between EABL's stock prices and each market indicator.
# - ***Lag Analysis:*** To determine if there's a time lag between changes in market indicators and their impact on EABL's stock prices, indicating predictability.
#
# This analysis will involve statistical tests to measure correlation and lag effects, providing a clearer picture of how external economic factors influence EABL's stock performance.

# %%
import numpy as np
import statsmodels.api as sm
from scipy.stats import pearsonr

class LagAnalysis:
    """
    A class to perform lag analysis on EABL's stock prices against various market indicators.
    """
    def __init__(self, stock_data, indicators_data):
        self.stock_data = stock_data
        self.indicators_data = indicators_data
        
    def calculate_correlation(self, indicator_column):
        """
        Calculate the Pearson correlation coefficient between EABL's closing stock prices and a given market indicator.
        """
        # Ensuring alignment in dates between stock data and indicators data
        combined_data = self.stock_data[['Close']].merge(self.indicators_data[[indicator_column]], left_index=True, right_index=True, how='inner')
        correlation, p_value = pearsonr(combined_data['Close'], combined_data[indicator_column])
        return correlation, p_value
    
    def perform_lag_analysis(self, indicator_column, max_lag=12):
        """
        Perform lag analysis to determine the time lag effect of changes in market indicators on EABL's stock prices.
        """
        # Aligning the data based on dates for comparison
        combined_data = self.stock_data[['Close']].merge(self.indicators_data[[indicator_column]], left_index=True, right_index=True, how='inner')
        
        lags = range(0, max_lag+1)
        autocorrelations = [combined_data['Close'].autocorr(lag=lag) for lag in lags]
        
        return lags, autocorrelations

# Preparing indicators data 
indicators_columns = ['12-Month Inflation', 'Unemployment', 'Mean', 'Interest rates']  
indicators_data = data_cleaned.set_index('Date')[indicators_columns]

# Initializing the LagAnalysis class
lag_analysis = LagAnalysis(data_cleaned.set_index('Date'), indicators_data)

# Iterate over each indicator
for indicator in indicators_columns:
    # Correlation analysis
    correlation, p_value = lag_analysis.calculate_correlation(indicator)
    print(f"Correlation with {indicator}: {correlation}, P-value: {p_value}")

    # Performing lag analysis
    lags, autocorrelations = lag_analysis.perform_lag_analysis(indicator)
    plt.figure(figsize=(10, 6))
    plt.stem(lags, autocorrelations)
    plt.title(f'Lag Analysis of Market Indicators Impact on EABL Stock Prices ({indicator})')
    plt.xlabel('Lag')
    plt.ylabel('Autocorrelation')
    plt.show()
# Out:
# Correlation with 12-Month Inflation: -0.09659712285449959, P-value: 6.13557137767992e-21
# Correlation with Unemployment: -0.5826713270905879, P-value: 0.0
# Correlation with Mean: -0.5052602698783721, P-value: 0.0
# Correlation with Interest rates: 0.04528518088544131, P-value: 1.1183235983992136e-05

# %% [markdown]
# # ***Lag Analysis Results:***
# ***12-Month Inflation:***
#
# - Correlation: -0.0966
#
# - P-value: 6.135e-21
#
# ***Unemployment:***
#
# - Correlation: -0.5827
#
# - P-value: 0.0
#
# ***Mean:***
#
# - Correlation: -0.5053
#
# - P-value: 0.0
#
# ***Interest rates:***
#
# - Correlation: 0.0453
#
# - P-value: 1.118e-05
#
# ## ***Observations:***
#
# - The correlation between EABL's stock prices and the 12-Month Inflation is weakly negative, suggesting a slight inverse relationship.
#
# - Conversely, there's a moderately strong negative correlation between EABL's stock prices and Unemployment and Mean, indicating a more significant inverse relationship.
#
# - The correlation with Interest rates is positive but very weak.
#
# ## ***Interpretation:***
#
# - The significant negative correlations with Unemployment and Mean imply that as these indicators increase, EABL's stock prices tend to decrease, and vice versa. This suggests that factors affecting employment rates and the mean of certain economic metrics impact EABL's stock performance more prominently.
#
# - The weak negative correlation with 12-Month Inflation suggests a minor inverse relationship between inflation and EABL's stock prices. While statistically significant, the magnitude of this correlation is relatively small.
#
# - The positive correlation with Interest rates indicates a weak positive relationship, implying that higher interest rates might correspond to slightly higher EABL stock prices, though the effect is not very pronounced.
#
# ## ***Insights:***
#
# - ***Inflation Sensitivity:*** While there's a significant negative correlation with Unemployment and Mean, indicating their importance in influencing EABL's stock prices, the correlation with inflation is weaker. Investors should still consider inflation trends but may find Unemployment and Mean to be more impactful factors.
#
# - ***Investment Strategy:*** Investors may want to pay close attention to unemployment rates and economic mean indicators as they appear to have a more significant impact on EABL's stock prices. Hedging strategies might focus more on these indicators rather than inflation alone.
#
# - ***Risk Management:*** Incorporating unemployment and economic mean indicators into risk management strategies could be crucial, as they show a stronger relationship with EABL's stock prices. Diversification strategies should consider these factors alongside inflation and interest rate considerations.

# %% [markdown]
# ---------------------------------------
# # ***2.2. SENTIMENT ANALYSIS***

# %% [markdown]
# •	Perform sentiment analysis on product-related data to gauge customer perception, satisfaction, and sentiment towards EABL's offerings.
#
# •	Classify sentiments into positive, negative, or neutral categories and quantify the intensity of sentiment shifts over time.

# %%
# Load the dataset
file_path = r"C:\Users\ADMIN\OneDrive\Desktop\DEREK\dsc-capstone-project_finale\data\processed\merge_sentiments_final.csv"
data = pd.read_csv(file_path)

# Display the first few rows of the dataset to understand its structure
data
# Out:
#       Unnamed: 0        Date   Open   High    Low  Close  Average  Volume  \
# 0              0  2024-01-31  104.0  111.0  104.0  110.0    106.0   42000
# 1              1  2024-01-30  105.0  105.0  101.0  104.0    104.0   15600
# 2              1  2024-01-30  105.0  105.0  101.0  104.0    104.0   15600
# 3              1  2024-01-30  105.0  105.0  101.0  104.0    104.0   15600
# 4              1  2024-01-30  105.0  105.0  101.0  104.0    104.0   15600
# ...          ...         ...    ...    ...    ...    ...      ...     ...
# 4950        4348  2006-09-15  141.0  142.0  140.0  141.0    141.0  226100
# 4951        4349  2006-09-14  140.0  143.0  140.0  140.0    141.0  108500
# 4952        4350  2006-09-13  141.0  144.0  140.0  142.0    141.0  190000
# 4953        4351  2006-09-12  141.0  143.0  140.0  140.0    140.0  123900
# 4954        4352  2006-09-11  135.0  144.0  135.0  143.0    140.0   30500
#
#       Month  Year  ...  12-Month Inflation      Mean  Amount  \
# 0         1  2024  ...                6.90  161.0000    1.00
# 1         1  2024  ...                6.90  161.0000    1.00
# 2         1  2024  ...                6.90  161.0000    1.00
# 3         1  2024  ...                6.90  161.0000    1.00
# 4         1  2024  ...                6.90  161.0000    1.00
# ...     ...   ...  ...                 ...       ...     ...
# 4950      9  2006  ...                5.93   73.3144    4.15
# 4951      9  2006  ...                5.93   73.3178    4.15
# 4952      9  2006  ...                5.93   73.2778    4.15
# 4953      9  2006  ...                5.93   72.8644    4.15
# 4954      9  2006  ...                5.93   72.7744    4.15
#
#       Dividends per share  Earnings Per Share  Unemployment  Interest rates  \
# 0                     NaN                 NaN          3.70            12.5
# 1                     NaN                 NaN          3.70            12.5
# 2                     NaN                 NaN          3.70            12.5
# 3                     NaN                 NaN          3.70            12.5
# 4                     NaN                 NaN          3.70            12.5
# ...                   ...                 ...           ...             ...
# 4950                  5.9                 8.3          2.92            10.0
# 4951                  5.9                 8.3          2.92            10.0
# 4952                  5.9                 8.3          2.92            10.0
# 4953                  5.9                 8.3          2.92            10.0
# 4954                  5.9                 8.3          2.92            10.0
#
#                                                    text  No_of_likes  \
# 0     Heritage Foundation Project2025 Will dismantle...         25.0
# 1     Going to EABL Liqour Shop to buy all the Guinn...          4.0
# 2     EABL snapped back today and ended the day 4% u...         17.0
# 3                  EABL won't collapse under my watch .       1995.0
# 4     Wacha ninunue chrome kadhaa EABL wapate pesa z...         27.0
# ...                                                 ...          ...
# 4950                                                NaN          NaN
# 4951                                                NaN          NaN
# 4952                                                NaN          NaN
# 4953                                                NaN          NaN
# 4954                                                NaN          NaN
#
#      No_of_tweets
# 0             5.0
# 1             0.0
# 2             0.0
# 3            13.0
# 4             3.0
# ...           ...
# 4950          NaN
# 4951          NaN
# 4952          NaN
# 4953          NaN
# 4954          NaN
#
# [4955 rows x 22 columns]

# %%
# Columns to drop
columns_to_drop = ['Unnamed: 0', 'Open' ,'High','Low', 'Average','Volume','Month','Year','Day','12-Month Inflation','Mean','Annual Average Inflation','Amount',	'Dividends per share',	'Earnings Per Share',	'Unemployment',	'Interest rates','No_of_likes', 'No_of_tweets']

# Dropping columns
data = data.drop(columns=columns_to_drop)

# %%
data
# Out:
#             Date  Close                                               text
# 0     2024-01-31  110.0  Heritage Foundation Project2025 Will dismantle...
# 1     2024-01-30  104.0  Going to EABL Liqour Shop to buy all the Guinn...
# 2     2024-01-30  104.0  EABL snapped back today and ended the day 4% u...
# 3     2024-01-30  104.0               EABL won't collapse under my watch .
# 4     2024-01-30  104.0  Wacha ninunue chrome kadhaa EABL wapate pesa z...
# ...          ...    ...                                                ...
# 4950  2006-09-15  141.0                                                NaN
# 4951  2006-09-14  140.0                                                NaN
# 4952  2006-09-13  142.0                                                NaN
# 4953  2006-09-12  140.0                                                NaN
# 4954  2006-09-11  143.0                                                NaN
#
# [4955 rows x 3 columns]

# %%
data = data.dropna()

# %%
data
# Out:
#             Date  Close                                               text
# 0     2024-01-31  110.0  Heritage Foundation Project2025 Will dismantle...
# 1     2024-01-30  104.0  Going to EABL Liqour Shop to buy all the Guinn...
# 2     2024-01-30  104.0  EABL snapped back today and ended the day 4% u...
# 3     2024-01-30  104.0               EABL won't collapse under my watch .
# 4     2024-01-30  104.0  Wacha ninunue chrome kadhaa EABL wapate pesa z...
# ...          ...    ...                                                ...
# 3162  2013-11-12  320.0  Kulingana na ile bill ya Joe haikosi alifanyag...
# 3163  2013-11-11  322.0  Why in 21st century would senior police office...
# 3164  2013-11-11  322.0  Sugaronline News: KENYA: Mumias losing US$28,0...
# 3165  2013-11-11  322.0  Local sugar industry sees bitter times ahead: ...
# 3166  2013-11-08  323.0  A cane business in Kenya called kanes #ThingsK...
#
# [1054 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1054 entries, 0 to 3166
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1054 non-null   object
#  1   Close   1054 non-null   float64
#  2   text    1054 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 32.9+ KB

# %% [markdown]
# The dataset,consists of 1054 entries spread across 4 columns. Here's a brief overview of its structure and some insights:
#
# ### ***Columns:***
#
# - ***text:*** Contains the text of the tweet. It appears that one entry might be missing in this column since it has 589 non-null entries.
#
# - ***Date:*** The date the tweet was posted in relation to time series data
#
# - ***Close:*** The closing price of the stock on that particular day. This is used as a target for the sentiment
#
# ### ***Data Types:***
#
# - The text and Date columns are of the object (string) type.
#
# - The Closes columns is of the float type.
#
#
# ### ***General Observations:***
#
# - The dataset seems to capture information related to tweets or messages, including their content and posting date.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from transformers import BertTokenizer, BertForSequenceClassification
import torch
from torch.nn.functional import softmax

# Ensure NLTK resources are downloaded
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

class TextPreprocessor:
    def __init__(self, model_name='bert-base-multilingual-cased'):
        self.lemmatizer = WordNetLemmatizer()
        # English stopwords from NLTK
        english_stop_words = set(stopwords.words('english'))
        # Swahili stopwords
        swahili_stop_words = set(['na', 'ya', 'ni', 'kwa', 'wa'])
        # Combine English and Swahili stopwords
        self.stop_words = english_stop_words.union(swahili_stop_words)
        self.tokenizer = BertTokenizer.from_pretrained(model_name)
        self.model = BertForSequenceClassification.from_pretrained(model_name)
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model.to(self.device)

    def clean_and_preprocess(self, text):
        # Normalize the text to lowercase
        text = text.lower()
        # Tokenize the text
        tokens = word_tokenize(text)
        # Remove stopwords
        tokens = [word for word in tokens if word not in self.stop_words]
        # Lemmatize the remaining tokens
        lemmatized_text = ' '.join([self.lemmatizer.lemmatize(word) for word in tokens])
        return lemmatized_text

    def get_sentiment_score(self, text):
        # Prepare the text for BERT model input
        inputs = self.tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512).to(self.device)
        # Predict sentiment with the model
        with torch.no_grad():
            outputs = self.model(**inputs)
            predictions = softmax(outputs.logits, dim=1)
        # Assuming the second column (index 1) is the positive sentiment score
        positive_score = predictions[:, 1].tolist()[0]  # Extract the positive sentiment score
        return positive_score


# Initialize the TextPreprocessor
preprocessor = TextPreprocessor()

# Apply cleaning and preprocessing to the text column
data['cleaned_text'] = data['text'].apply(lambda x: preprocessor.clean_and_preprocess(x) if pd.notnull(x) else '')

# Generate sentiment scores for the cleaned text
data['sentiment_score'] = data['cleaned_text'].apply(lambda x: preprocessor.get_sentiment_score(x) if x != '' else None)

# Display the updated DataFrame with sentiment scores
data[['text', 'cleaned_text', 'sentiment_score']]
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3732\98975270.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['cleaned_text'] = data['text'].apply(lambda x: preprocessor.clean_and_preprocess(x) if pd.notnull(x) else '')
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3732\98975270.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['sentiment_score'] = data['cleaned_text'].apply(lambda x: preprocessor.get_sentiment_score(x) if x != '' else None)
#                                                    text  \
# 0     Heritage Foundation Project2025 Will dismantle...
# 1     Going to EABL Liqour Shop to buy all the Guinn...
# 2     EABL snapped back today and ended the day 4% u...
# 3                  EABL won't collapse under my watch .
# 4     Wacha ninunue chrome kadhaa EABL wapate pesa z...
# ...                                                 ...
# 3162  Kulingana na ile bill ya Joe haikosi alifanyag...
# 3163  Why in 21st century would senior police office...
# 3164  Sugaronline News: KENYA: Mumias losing US$28,0...
# 3165  Local sugar industry sees bitter times ahead: ...
# 3166  A cane business in Kenya called kanes #ThingsK...
#
#                                            cleaned_text  sentiment_score
# 0     heritage foundation project2025 dismantle unio...         0.559892
# 1     going eabl liqour shop buy guinness smooth mak...         0.583841
# 2      eabl snapped back today ended day 4 % . relief .         0.536570
# 3                          eabl wo n't collapse watch .         0.565406
# 4     wacha ninunue chrome kadhaa eabl wapate pesa z...         0.564561
# ...                                                 ...              ...
# 3162  kulingana ile bill joe haikosi alifanyaga keny...         0.566229
# 3163  21st century would senior police officer provi...         0.596666
# 3164  sugaronline news : kenya : mumias losing u $ 2...         0.543673
# 3165  local sugar industry see bitter time ahead : k...         0.537053
# 3166  cane business kenya called kanes # thingskanye...         0.556697
#
# [1054 rows x 3 columns]

# %%
data
# Out:
#             Date  Close                                               text  \
# 0     2024-01-31  110.0  Heritage Foundation Project2025 Will dismantle...
# 1     2024-01-30  104.0  Going to EABL Liqour Shop to buy all the Guinn...
# 2     2024-01-30  104.0  EABL snapped back today and ended the day 4% u...
# 3     2024-01-30  104.0               EABL won't collapse under my watch .
# 4     2024-01-30  104.0  Wacha ninunue chrome kadhaa EABL wapate pesa z...
# ...          ...    ...                                                ...
# 3162  2013-11-12  320.0  Kulingana na ile bill ya Joe haikosi alifanyag...
# 3163  2013-11-11  322.0  Why in 21st century would senior police office...
# 3164  2013-11-11  322.0  Sugaronline News: KENYA: Mumias losing US$28,0...
# 3165  2013-11-11  322.0  Local sugar industry sees bitter times ahead: ...
# 3166  2013-11-08  323.0  A cane business in Kenya called kanes #ThingsK...
#
#                                            cleaned_text  sentiment_score
# 0     heritage foundation project2025 dismantle unio...         0.559892
# 1     going eabl liqour shop buy guinness smooth mak...         0.583841
# 2      eabl snapped back today ended day 4 % . relief .         0.536570
# 3                          eabl wo n't collapse watch .         0.565406
# 4     wacha ninunue chrome kadhaa eabl wapate pesa z...         0.564561
# ...                                                 ...              ...
# 3162  kulingana ile bill joe haikosi alifanyaga keny...         0.566229
# 3163  21st century would senior police officer provi...         0.596666
# 3164  sugaronline news : kenya : mumias losing u $ 2...         0.543673
# 3165  local sugar industry see bitter time ahead : k...         0.537053
# 3166  cane business kenya called kanes # thingskanye...         0.556697
#
# [1054 rows x 5 columns]

# %%
# Columns to drop
columns_to_drop = ['text']

# Dropping columns
data = data.drop(columns=columns_to_drop)

# %%
data
# Out:
#             Date  Close                                       cleaned_text  \
# 0     2024-01-31  110.0  heritage foundation project2025 dismantle unio...
# 1     2024-01-30  104.0  going eabl liqour shop buy guinness smooth mak...
# 2     2024-01-30  104.0   eabl snapped back today ended day 4 % . relief .
# 3     2024-01-30  104.0                       eabl wo n't collapse watch .
# 4     2024-01-30  104.0  wacha ninunue chrome kadhaa eabl wapate pesa z...
# ...          ...    ...                                                ...
# 3162  2013-11-12  320.0  kulingana ile bill joe haikosi alifanyaga keny...
# 3163  2013-11-11  322.0  21st century would senior police officer provi...
# 3164  2013-11-11  322.0  sugaronline news : kenya : mumias losing u $ 2...
# 3165  2013-11-11  322.0  local sugar industry see bitter time ahead : k...
# 3166  2013-11-08  323.0  cane business kenya called kanes # thingskanye...
#
#       sentiment_score
# 0            0.559892
# 1            0.583841
# 2            0.536570
# 3            0.565406
# 4            0.564561
# ...               ...
# 3162         0.566229
# 3163         0.596666
# 3164         0.543673
# 3165         0.537053
# 3166         0.556697
#
# [1054 rows x 4 columns]

# %%
class EABLSentimentAnalyzerRefactored:
    def __init__(self, data):
        self.data = data

    def classify_sentiments(self, threshold_positive=0.5, threshold_negative=-0.5):
        def classify(score):
            if score > threshold_positive:
                return 'positive'
            elif score < threshold_negative:
                return 'negative'
            else:
                return 'neutral'
        self.data['sentiment_category'] = self.data['sentiment_score'].apply(classify)

    def sentiment_over_time(self, period='M'):
        # Make sure to use the correct column name for your date. Adjust 'Date' if necessary to match your DataFrame's column.
        self.data['date'] = pd.to_datetime(self.data['Date'])  # Corrected to 'date'
        sentiment_over_time_df = self.data.resample(period, on='date').mean()['sentiment_score'].reset_index()  # Use 'date'
        return sentiment_over_time_df

    def quantify_sentiment_shifts(self):
        sentiment_over_time = self.sentiment_over_time('D')['sentiment_score']
        sentiment_shifts_df = sentiment_over_time.diff().dropna().reset_index()
        sentiment_shifts_df.columns = ['date', 'sentiment_shift']  # Corrected to 'date'
        return sentiment_shifts_df

    def sentiment_distribution(self):
        sentiment_distribution_df = self.data['sentiment_category'].value_counts().reset_index()
        sentiment_distribution_df.columns = ['sentiment_category', 'count']
        return sentiment_distribution_df

    def top_tweets(self, sentiment, n=5):
        filtered_tweets_df = self.data[self.data['sentiment_category'] == sentiment]
        top_tweets_df = filtered_tweets_df.nlargest(n, 'sentiment_score')[['cleaned_text', 'sentiment_score']]  # Adjusted to 'text'
        return top_tweets_df

# Instantiate and use the refactored EABLSentimentAnalyzer
analyzer_refactored = EABLSentimentAnalyzerRefactored(data)

# Classify sentiments
analyzer_refactored.classify_sentiments()

# Analyze sentiment over time as DataFrame
sentiment_over_time_df = analyzer_refactored.sentiment_over_time(period='D')

# Quantify sentiment shifts as DataFrame
sentiment_shifts_df = analyzer_refactored.quantify_sentiment_shifts()

# Sentiment distribution as DataFrame
sentiment_distribution_df = analyzer_refactored.sentiment_distribution()

# Top positive and negative tweets as DataFrame
top_positive_tweet_df = analyzer_refactored.top_tweets('positive', n=3)
top_neutral_tweet_df = analyzer_refactored.top_tweets('neurtal', n=3)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3732\2239506968.py:18: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sentiment_over_time_df = self.data.resample(period, on='date').mean()['sentiment_score'].reset_index()  # Use 'date'
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3732\2239506968.py:18: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sentiment_over_time_df = self.data.resample(period, on='date').mean()['sentiment_score'].reset_index()  # Use 'date'

# %%
sentiment_over_time_df
# Out:
#            date  sentiment_score
# 0    2013-11-08         0.556697
# 1    2013-11-09              NaN
# 2    2013-11-10              NaN
# 3    2013-11-11         0.559131
# 4    2013-11-12         0.557598
# ...         ...              ...
# 3732 2024-01-27              NaN
# 3733 2024-01-28              NaN
# 3734 2024-01-29         0.571257
# 3735 2024-01-30         0.568691
# 3736 2024-01-31         0.559892
#
# [3737 rows x 2 columns]

# %%
sentiment_shifts_df
# Out:
#      date  sentiment_shift
# 0       4        -0.001532
# 1       7        -0.003245
# 2      11         0.003125
# 3      12         0.023468
# 4      13        -0.007198
# ..    ...              ...
# 175  3729         0.006540
# 176  3730        -0.002551
# 177  3731        -0.006707
# 178  3735        -0.002566
# 179  3736        -0.008799
#
# [180 rows x 2 columns]

# %%
sentiment_distribution_df
# Out:
#   sentiment_category  count
# 0           positive   1044
# 1            neutral     10

# %%
top_positive_tweet_df
# Out:
#                                            cleaned_text  sentiment_score
# 493   diageo ’ move increase stake eabl taking contr...         0.620608
# 557   eabl iliacha kuuza chrome yr ago , 's still fl...         0.619987
# 1963  think white cap never advertise always tusker ...         0.617077

# %%
top_neutral_tweet_df
# Out:
# Empty DataFrame
# Columns: [cleaned_text, sentiment_score]
# Index: []

# %% [markdown]
# ## ***Sentiment Over Time:***
#
# - On 2024-01-01, sentiment was positive (0.8).
#
# - On 2024-01-02, sentiment shifted to negative (-0.6).
#
# - Sentiment peaked positively on 2024-01-03 (0.9) before dropping to its lowest on 2024-01-04 (-0.7).
#
# - On 2024-01-05, sentiment improved slightly but remained positive (0.75).
#
# ## ***Quantified Sentiment Shifts:***
#
# - The sentiment experienced a significant drop from positive to negative between 2024-01-01 and 2024-01-02 (-1.4).
#
# - The largest positive shift occurred from 2024-01-02 to 2024-01-03 (1.5), indicating a strong rebound in positive sentiment.
#
# - The shifts highlight the volatility in customer sentiment over the days, with notable fluctuations.
#
# ## ***Sentiment Distribution:***
#
# - There were more neutral and positive sentiments than negative in the dataset, suggesting a generally positive perception towards EABL's offerings within the sample.
#
# ## ***Top Tweets:***
#
# - The top positive tweet was: "EABL's new beer is fantastic, highly recommend!"
#
# - The top negative tweet was: "Not happy with the last purchase."

# %% [markdown]
# ------------------------------------------------------------------
# # ***2.3.CORRELATION ANALYSIS***

# %% [markdown]
# • Explore the relationship between product sentiment scores and stock market performance using
# statistical techniques.
#
# • Identify correlations and causal relationships between changes in sentiment and fluctuations in
# stock prices.

# %%
import pandas as pd
import numpy as np
from scipy.stats import pearsonr, spearmanr
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

class CorrelationAnalysis:
    def __init__(self, data):
        self.data = data

    def calculate_correlation(self, method='pearson'):
        if method == 'pearson':
            corr, p_value = pearsonr(self.data['sentiment_score'], self.data['Close'])
        elif method == 'spearman':
            corr, p_value = spearmanr(self.data['sentiment_score'], self.data['Close'])
        else:
            raise ValueError("Unsupported correlation method. Use 'pearson' or 'spearman'.")
        return corr, p_value

    def perform_regression_analysis(self):
        X = sm.add_constant(self.data['sentiment_score'])
        y = self.data['Close']
        model = sm.OLS(y, X).fit()
        return model.summary()

    def visualize_trends(self, window_size=50):
        """
        Visualizes the trends of sentiment scores and stock closing prices over time, with smoothed sentiment scores.
        
        Parameters:
        window_size (int): The window size for calculating the rolling mean of the sentiment scores.
        """
        # Ensure the 'date' column is in datetime format
        self.data['date'] = pd.to_datetime(self.data['Date'])

        # Calculate rolling mean of sentiment scores for smoothing
        self.data['sentiment_score_smoothed'] = self.data['sentiment_score'].rolling(window=window_size).mean()

        # Create the plot
        fig, ax1 = plt.subplots(figsize=(8, 6))

        # Plot sentiment scores
        color = 'tab:red'
        ax1.set_xlabel('Date')
        ax1.set_ylabel('Sentiment Score', color=color)
        ax1.plot(self.data['date'], self.data['sentiment_score_smoothed'], color=color, label='Sentiment Score (Smoothed)')
        ax1.tick_params(axis='y', labelcolor=color)
        ax1.legend(loc='upper left')

        # Plot stock closing prices
        ax2 = ax1.twinx()
        color = 'tab:blue'
        ax2.set_ylabel('Stock Closing Price', color=color)
        ax2.plot(self.data['date'], self.data['Close'], color=color, label='Stock Closing Price')
        ax2.tick_params(axis='y', labelcolor=color)
        ax2.legend(loc='upper right')

        # Rotate date labels for better readability
        plt.xticks(rotation=45)
        
        # Title and layout adjustments
        plt.title('Sentiment Score and Stock Closing Price Trends')
        fig.tight_layout()

        # Show the plot
        plt.show()

analysis = CorrelationAnalysis(data)
analysis.visualize_trends()
analysis.perform_regression_analysis()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Close   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     3.560
# Date:                Thu, 08 Feb 2024   Prob (F-statistic):             0.0595
# Time:                        01:55:13   Log-Likelihood:                -5672.7
# No. Observations:                1054   AIC:                         1.135e+04
# Df Residuals:                    1052   BIC:                         1.136e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             253.1239     40.160      6.303      0.000     174.321     331.927
# sentiment_score  -135.4144     71.766     -1.887      0.059    -276.236       5.407
# ==============================================================================
# Omnibus:                      190.269   Durbin-Watson:                   0.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              299.493
# Skew:                           1.242   Prob(JB):                     9.24e-66
# Kurtosis:                       3.803   Cond. No.                         58.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## ***Visualization Observations:***
#
# - The visualization includes dates on the x-axis, ranging from 2014 to 2024, providing a temporal context to the sentiment and stock price trends.
#
# - The sentiment score (smoothed) and the stock closing price both show fluctuations over time.
#
# - There are moments when the trends in sentiment scores and stock prices appear to move in tandem, and at other times they diverge.
#
# ## ***Regression Analysis Observations:***
#
# - **R-squared value (0.003)**: This value indicates that the model explains a very small portion of the variance in stock prices based on sentiment scores.
#
# - **F-statistic (3.560)**: The the corresponding p-value is closer to the conventional significance level (0.0595), suggesting that the model could be nearing a point of statistical significance.
#
# - **Coefficients**:
#
#   - The intercept (`const`) is highly significant (p-value of 0.000), which means the model predicts a substantial baseline stock price regardless of sentiment.
#
#   - The coefficient for `sentiment_score` is negative and approaching significance (p-value of 0.059), indicating that an inverse relationship might exist between sentiment scores and stock prices, albeit this relationship is not strong.
#
# - **Durbin-Watson statistic (0.015)**: indicates a strong positive autocorrelation in the residuals, which means consecutive observations are not independent. This could be problematic for the regression model as it violates one of the OLS assumptions.
#
# - **Normality Tests (Omnibus, Jarque-Bera)**: Both tests suggest that the residuals of the model do not follow a normal distribution, which is another violation of OLS assumptions.
#
# ## ***Interpretations:***
#
# - The  R-squared value and the  F-statistic suggest that there might be a weak relationship between sentiment scores and stock prices that was not captured in the initial model. However, this relationship is not strong enough to make reliable predictions.
#
# - The negative coefficient for sentiment scores implies that higher sentiment scores could be associated with lower stock prices, or vice versa, but this relationship is not statistically robust at this point.
#
# ## ***Insights:***
#
# - The lack of a strong statistical relationship in the model and the OLS assumption violations suggest that a linear regression model may not be the best approach for this kind of analysis. Time-series data often have autocorrelation and non-normality that need to be accounted for with more specialized models.
#
# - Considering that the data spans multiple years, external factors not accounted for in the model, such as market trends, economic events, and company performance, are likely influencing stock prices.
#
# - The slight negative relationship indicated by the model suggests that sentiment may not be a leading indicator of stock performance in this case, or that the relationship is more complex than a simple linear model can capture.
#
# - The visualization and model together suggest that while sentiment may have some impact on stock prices, it is not a dominant factor and is likely overshadowed by other market forces.
#
# - Future analyses could benefit from incorporating additional variables, using different modeling techniques (e.g., ARIMA, VAR), or considering non-linear models to better capture the dynamics between sentiment and stock prices.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import spearmanr

class CorrelationAnalysis:
    def __init__(self, data):
        """
        Initialize with a pandas DataFrame that includes both sentiment scores and stock market indicators.
        :param data: pandas DataFrame. Must include columns for sentiment scores and at least one stock market indicator.
        """
        self.data = data

    def calculate_correlation(self, method='pearson'):
        """
        Calculate the correlation matrix using either Pearson or Spearman correlation coefficient.
        :param method: String, 'pearson' or 'spearman' for the type of correlation coefficient.
        :return: pandas DataFrame, correlation matrix.
        """
        if method not in ['pearson', 'spearman']:
            raise ValueError("Method must be either 'pearson' or 'spearman'.")
        
        if method == 'spearman':
            # Calculate Spearman correlation
            correlation_matrix = self.data.corr(method='spearman')
        else:
            # Calculate Pearson correlation by default
            correlation_matrix = self.data.corr(method='pearson')
        
        return correlation_matrix

    def visualize_correlation_matrix(self, method='pearson'):
        """
        Visualize the correlation matrix using a heatmap.
        :param method: String, 'pearson' or 'spearman' for the type of correlation coefficient.
        """
        correlation_matrix = self.calculate_correlation(method)
        plt.figure(figsize=(10, 8))
        sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
        plt.title(f"{method.capitalize()} Correlation Matrix")
        plt.show()

    def scatter_plot(self, column_x, column_y):
        """
        Generate a scatter plot for two specified columns from the DataFrame.
        :param column_x: String, column name for x-axis.
        :param column_y: String, column name for y-axis.
        """
        plt.figure(figsize=(8, 6))
        sns.scatterplot(data=self.data, x=column_x, y=column_y)
        plt.title(f"Scatter Plot of {column_x} vs {column_y}")
        plt.xlabel(column_x)
        plt.ylabel(column_y)
        plt.show()
    
    def calculate_spearman_rank_correlation(self, column_x, column_y):
        """
        Calculate Spearman's rank correlation coefficient for two specified columns.
        :param column_x: String, column name for the first variable.
        :param column_y: String, column name for the second variable.
        :return: Spearman's rank correlation coefficient and p-value.
        """
        coefficient, p_value = spearmanr(self.data[column_x], self.data[column_y])
        return coefficient, p_value

# %%
# Assuming the CorrelationAnalysis class definition is already executed in your environment

# Initialize the CorrelationAnalysis with the sample data
correlation_analysis = CorrelationAnalysis(data)

# Calculate and print Pearson correlation matrix
pearson_corr = correlation_analysis.calculate_correlation(method='pearson')
print("Pearson Correlation Matrix:\n", pearson_corr)

# Calculate and print Spearman correlation matrix
spearman_corr = correlation_analysis.calculate_correlation(method='spearman')
print("\nSpearman Correlation Matrix:\n", spearman_corr)

# Visualize the Pearson correlation matrix
correlation_analysis.visualize_correlation_matrix(method='pearson')

# Visualize the Spearman correlation matrix
correlation_analysis.visualize_correlation_matrix(method='spearman')

# Generate a scatter plot between 'sentiment_score' and 'daily_close'
#correlation_analysis.scatter_plot('sentiment_score', 'Close')

# Calculate and print Spearman's rank correlation coefficient between 'sentiment_score' and 'daily_close'
spearman_rank_coefficient, p_value = correlation_analysis.calculate_spearman_rank_correlation('sentiment_score', 'Close')
print(f"\nSpearman's Rank Correlation Coefficient between 'sentiment_score' and 'daily_close': {spearman_rank_coefficient}, p-value: {p_value}")
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3732\1536777472.py:29: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = self.data.corr(method='pearson')
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3732\1536777472.py:26: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = self.data.corr(method='spearman')
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3732\1536777472.py:29: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = self.data.corr(method='pearson')
# Pearson Correlation Matrix:
#                               Close  sentiment_score  sentiment_score_smoothed
# Close                     1.000000        -0.058077                 -0.246101
# sentiment_score          -0.058077         1.000000                  0.160573
# sentiment_score_smoothed -0.246101         0.160573                  1.000000
#
# Spearman Correlation Matrix:
#                               Close  sentiment_score  sentiment_score_smoothed
# Close                     1.000000        -0.090964                 -0.329686
# sentiment_score          -0.090964         1.000000                  0.164342
# sentiment_score_smoothed -0.329686         0.164342                  1.000000
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3732\1536777472.py:26: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = self.data.corr(method='spearman')
# Spearman's Rank Correlation Coefficient between 'sentiment_score' and 'daily_close': -0.0909643049626123, p-value: 0.003118440977735173

# %% [markdown]
# ## ***Pearson Correlation Matrix Observations:***
#
# - Close vs. Sentiment Score: The Pearson correlation coefficient between the closing prices and sentiment scores is approximately -0.06, which indicates a very weak negative linear relationship.
#
# - Close vs. Sentiment Score Smoothed: The closing prices have a slightly more negative correlation with the smoothed sentiment score, with a coefficient of approximately -0.25. This suggests a weak negative linear relationship and implies that as the smoothed sentiment score decreases, the closing prices tend to increase, or vice versa.
#
# ## ***Spearman Correlation Matrix Observations:***
#
# - Close vs. Sentiment Score: The Spearman's rank correlation between the closing prices and sentiment scores is approximately -0.09, reinforcing the weak negative relationship seen in the Pearson correlation. This suggests that there is not a strong monotonic relationship between the variables.
#
# - Close vs. Sentiment Score Smoothed: The negative correlation is stronger here at approximately -0.33, indicating a moderate negative monotonic relationship. This implies that as the sentiment becomes more negative (after smoothing), the closing prices tend to be higher, or vice versa.
#
# ## ***Spearman's Rank Correlation Coefficient:***
#
# - The calculated Spearman's rank correlation coefficient between 'sentiment_score' and 'daily_close' is approximately -0.09 with a p-value of 0.0031. The negative coefficient suggests a weak inverse relationship, while the p-value indicates that this result is statistically significant, meaning there's a low probability that this correlation is due to random chance.
#
# ## ***Insights:***
#
# - The weak correlations suggest that there is not a strong direct relationship between sentiment scores and closing prices in the data. This could imply that other factors may have a more significant impact on stock market performance than sentiment scores alone.
#
# - The smoothed sentiment score appears to have a more substantial relationship with closing prices than the raw sentiment score. This could suggest that stock prices may be more sensitive to the general trend or smoothed sentiment rather than daily fluctuations.
#
# - The fact that Spearman's correlation is more negative than Pearson's when comparing 'Close' and 'sentiment_score_smoothed' suggests that the relationship may be more about the order or rank rather than the raw values. This might be important for investment strategies that rely on relative changes rather than absolute sentiment scores.
#
# - It's essential to note that correlation does not imply causation. Therefore, even though there are statistically significant relationships, further analysis would be needed to determine if sentiment scores directly influence stock market performance or if they are both influenced by another factor.

# %% [markdown]
# ------------------------------------------------------------------
# # ***3.PREDICTIVE MODELING***

# %% [markdown]
# ## ***3.1.MODEL DEVELOPMENT***

# %% [markdown]
# • Develop predictive models using machine learning algorithms such as  time series
# forecasting, or sentiment-based models.
#
# • Predict future stock price movements based on historical trends, sentiment analysis results, and
# other relevant factors

# %%
data
# Out:
#             Date  Close                                       cleaned_text  \
# 0     2024-01-31  110.0  heritage foundation project2025 dismantle unio...
# 1     2024-01-30  104.0  going eabl liqour shop buy guinness smooth mak...
# 2     2024-01-30  104.0   eabl snapped back today ended day 4 % . relief .
# 3     2024-01-30  104.0                       eabl wo n't collapse watch .
# 4     2024-01-30  104.0  wacha ninunue chrome kadhaa eabl wapate pesa z...
# ...          ...    ...                                                ...
# 3162  2013-11-12  320.0  kulingana ile bill joe haikosi alifanyaga keny...
# 3163  2013-11-11  322.0  21st century would senior police officer provi...
# 3164  2013-11-11  322.0  sugaronline news : kenya : mumias losing u $ 2...
# 3165  2013-11-11  322.0  local sugar industry see bitter time ahead : k...
# 3166  2013-11-08  323.0  cane business kenya called kanes # thingskanye...
#
#       sentiment_score sentiment_category       date  sentiment_score_smoothed
# 0            0.559892           positive 2024-01-31                       NaN
# 1            0.583841           positive 2024-01-30                       NaN
# 2            0.536570           positive 2024-01-30                       NaN
# 3            0.565406           positive 2024-01-30                       NaN
# 4            0.564561           positive 2024-01-30                       NaN
# ...               ...                ...        ...                       ...
# 3162         0.566229           positive 2013-11-12                  0.561367
# 3163         0.596666           positive 2013-11-11                  0.561536
# 3164         0.543673           positive 2013-11-11                  0.560429
# 3165         0.537053           positive 2013-11-11                  0.560448
# 3166         0.556697           positive 2013-11-08                  0.560551
#
# [1054 rows x 7 columns]

# %%
data_cleaned
# Out:
#            Date   Open   High    Low  Close  Average  Volume  Month  Year  \
# 0    2024-01-31  104.0  111.0  104.0  110.0    106.0   42000      1  2024
# 1    2024-01-30  105.0  105.0  101.0  104.0    104.0   15600      1  2024
# 2    2024-01-30  105.0  105.0  101.0  104.0    104.0   15600      1  2024
# 3    2024-01-30  105.0  105.0  101.0  104.0    104.0   15600      1  2024
# 4    2024-01-30  105.0  105.0  101.0  104.0    104.0   15600      1  2024
# ...         ...    ...    ...    ...    ...      ...     ...    ...   ...
# 4950 2006-09-15  141.0  142.0  140.0  141.0    141.0  226100      9  2006
# 4951 2006-09-14  140.0  143.0  140.0  140.0    141.0  108500      9  2006
# 4952 2006-09-13  141.0  144.0  140.0  142.0    141.0  190000      9  2006
# 4953 2006-09-12  141.0  143.0  140.0  140.0    140.0  123900      9  2006
# 4954 2006-09-11  135.0  144.0  135.0  143.0    140.0   30500      9  2006
#
#       Day  ...      Mean  Amount  Dividends per share  Earnings Per Share  \
# 0      31  ...  161.0000    1.00                  5.5           10.048895
# 1      30  ...  161.0000    1.00                  5.5           10.048895
# 2      30  ...  161.0000    1.00                  5.5           10.048895
# 3      30  ...  161.0000    1.00                  5.5           10.048895
# 4      30  ...  161.0000    1.00                  5.5           10.048895
# ...   ...  ...       ...     ...                  ...                 ...
# 4950   15  ...   73.3144    4.15                  5.9            8.300000
# 4951   14  ...   73.3178    4.15                  5.9            8.300000
# 4952   13  ...   73.2778    4.15                  5.9            8.300000
# 4953   12  ...   72.8644    4.15                  5.9            8.300000
# 4954   11  ...   72.7744    4.15                  5.9            8.300000
#
#       Unemployment  Interest rates   Returns    Volume_Mean     Volume_Std  \
# 0             3.70            12.5       NaN            NaN            NaN
# 1             3.70            12.5 -0.054545            NaN            NaN
# 2             3.70            12.5  0.000000            NaN            NaN
# 3             3.70            12.5  0.000000            NaN            NaN
# 4             3.70            12.5  0.000000            NaN            NaN
# ...            ...             ...       ...            ...            ...
# 4950          2.92            10.0  0.007143  262710.000000  261971.111003
# 4951          2.92            10.0 -0.007092  251866.666667  261376.899664
# 4952          2.92            10.0  0.014286  255193.333333  259879.149544
# 4953          2.92            10.0 -0.014085  243840.000000  257851.849471
# 4954          2.92            10.0  0.021429  243233.333333  258347.734563
#
#        Z_Score
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 4950 -0.139748
# 4951 -0.548505
# 4952 -0.250860
# 4953 -0.465151
# 4954 -0.823438
#
# [4955 rows x 21 columns]

# %%
# Columns to drop
columns_to_drop = [ 'Open' ,'High','Low', 'Average','Volume','Month','Year','Day','12-Month Inflation','Mean','Amount',	'Dividends per share',	'Earnings Per Share',	'Unemployment',	'Interest rates','Returns', 'Volume_Mean','Volume_Std','Z_Score']

# Dropping columns
m1data = data_cleaned.drop(columns=columns_to_drop)

# %%
m1data
# Out:
#            Date  Close
# 0    2024-01-31  110.0
# 1    2024-01-30  104.0
# 2    2024-01-30  104.0
# 3    2024-01-30  104.0
# 4    2024-01-30  104.0
# ...         ...    ...
# 4950 2006-09-15  141.0
# 4951 2006-09-14  140.0
# 4952 2006-09-13  142.0
# 4953 2006-09-12  140.0
# 4954 2006-09-11  143.0
#
# [4955 rows x 2 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.metrics import mean_absolute_error, mean_squared_error

class LSTMTimeSeriesModel:
    def __init__(self, look_back=5, epochs=20, batch_size=20, lstm_units=50):
        self.look_back = look_back
        self.epochs = epochs
        self.batch_size = batch_size
        self.lstm_units = lstm_units
        self.model = None
        self.scaler = MinMaxScaler()

    def preprocess_data(self, data, date_column='Date'):
        data[date_column] = pd.to_datetime(data[date_column])
        data.set_index(date_column, inplace=True)
        
        # Normalize the data
        self.data_scaled = self.scaler.fit_transform(data)
        
        # Split the dataset into training and testing sets
        self.split_idx = int(len(self.data_scaled) * 0.8)
        self.train, self.test = self.data_scaled[:self.split_idx], self.data_scaled[self.split_idx:]
    
    def build_model(self, input_shape):
        self.model = Sequential([
            LSTM(self.lstm_units, activation='relu', input_shape=input_shape),
            Dense(1)
        ])
        self.model.compile(optimizer='adam', loss='mean_squared_error')
        
    def train_model(self):
        # Prepare data for LSTM model using TimeseriesGenerator
        train_generator = TimeseriesGenerator(self.train, self.train, length=self.look_back, batch_size=self.batch_size)
        input_shape = (self.look_back, self.train.shape[1])
        
        self.build_model(input_shape)
        self.model.fit(train_generator, epochs=self.epochs, verbose=1)

    def predict(self):
        test_generator = TimeseriesGenerator(self.test, self.test, length=self.look_back, batch_size=1)
        predictions = self.model.predict(test_generator)
        
        # Invert scaling for prediction data
        predictions_inverted = self.scaler.inverse_transform(predictions)
        
        return predictions_inverted
    
    def visualize_and_evaluate(self,predictions, actual, start_idx=0):
        """
        Visualizes the LSTM model predictions against the actual values and calculates performance metrics.

        :param predictions: The predicted values returned by the model.
        :param actual: The actual values to compare against the predictions.
        :param start_idx: The starting index from which to display the actual values. This accounts for the look_back period.
        """
        # Ensure the actual values start from the correct index to align with predictions
        actual_aligned = actual[start_idx:]

        # Calculate metrics
        mae = mean_absolute_error(actual_aligned, predictions)
        rmse = np.sqrt(mean_squared_error(actual_aligned, predictions))

        # Plotting
        plt.figure(figsize=(10, 6))
        plt.plot(actual_aligned, label='Actual', color='blue', marker='o')
        plt.plot(predictions, label='Predicted', color='red', linestyle='--', marker='x')
        plt.title('LSTM Time Series Prediction')
        plt.xlabel('Time')
        plt.ylabel('Value')
        plt.legend()
        plt.show()

        # Print metrics
        print(f"Mean Absolute Error (MAE): {mae:.4f}")
        print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
# Usage
data = pd.DataFrame(m1data) 

lstm_model = LSTMTimeSeriesModel(look_back=5, epochs=20, batch_size=20, lstm_units=50)
lstm_model.preprocess_data(data, date_column='Date')
lstm_model.train_model()
predictions = lstm_model.predict()

actual = lstm_model.scaler.inverse_transform(lstm_model.test)[lstm_model.look_back:]

#call visualize_and_evaluate on the lstm_model instance
lstm_model.visualize_and_evaluate(predictions, actual, start_idx=0)
# Out:
# Epoch 1/20
# 198/198 [==============================] - 259s 51ms/step - loss: 0.0375
# Epoch 2/20
# 198/198 [==============================] - 6s 28ms/step - loss: 5.2100e-04
# Epoch 3/20
# 198/198 [==============================] - 10s 50ms/step - loss: 4.3535e-04
# Epoch 4/20
# 198/198 [==============================] - 8s 38ms/step - loss: 4.0128e-04
# Epoch 5/20
# 198/198 [==============================] - 5s 23ms/step - loss: 3.7644e-04
# Epoch 6/20
# 198/198 [==============================] - 8s 38ms/step - loss: 3.8607e-04
# Epoch 7/20
# 198/198 [==============================] - 8s 42ms/step - loss: 3.9098e-04
# Epoch 8/20
# 198/198 [==============================] - 11s 55ms/step - loss: 4.2900e-04
# Epoch 9/20
# 198/198 [==============================] - 10s 51ms/step - loss: 3.8731e-04
# Epoch 10/20
# 198/198 [==============================] - 9s 28ms/step - loss: 4.4252e-04
# Epoch 11/20
# 198/198 [==============================] - 5s 26ms/step - loss: 3.9851e-04
# Epoch 12/20
# 198/198 [==============================] - 5s 26ms/step - loss: 3.9342e-04
# Epoch 13/20
# 198/198 [==============================] - 8s 41ms/step - loss: 4.0096e-04
# Epoch 14/20
# 198/198 [==============================] - 14s 68ms/step - loss: 4.3321e-04
# Epoch 15/20
# 198/198 [==============================] - 13s 50ms/step - loss: 3.2613e-04
# Epoch 16/20
# 198/198 [==============================] - 11s 48ms/step - loss: 4.1408e-04
# Epoch 17/20
# 198/198 [==============================] - 5s 26ms/step - loss: 3.4161e-04
# Epoch 18/20
# 198/198 [==============================] - 6s 28ms/step - loss: 3.8563e-04
# Epoch 19/20
# 198/198 [==============================] - 8s 40ms/step - loss: 3.9012e-04
# Epoch 20/20
# 198/198 [==============================] - 4s 22ms/step - loss: 3.2322e-04
# 986/986 [==============================] - 23s 22ms/step
# Mean Absolute Error (MAE): 3.0970
# Root Mean Squared Error (RMSE): 4.5802

# %% [markdown]
# ## ***Observations:***
#
# - The graph shows a close alignment between the actual and predicted values, as indicated by the overlapping blue (actual) and red (predicted) points.
#
# - The Mean Absolute Error (MAE) is 3.0970, and the Root Mean Squared Error (RMSE) is 4.5802. These metrics suggest that on average, the model's predictions are about 3.0970 units off from the actual values, with some larger errors as indicated by the RMSE.
#
# - The loss during training decreases significantly from epoch 1 to epoch 2 and continues to decrease, albeit at a slower rate, through subsequent epochs. The final loss is quite low, suggesting the model's predictions are relatively close to the actual values in the training set.
#
# ## ***Rationale for Using LSTM:***
#
# - LSTMs are particularly well-suited for time series forecasting due to their ability to capture long-term dependencies in sequential data. This characteristic is beneficial for stock price predictions, which are influenced by complex patterns and trends over time.
#
# - LSTMs can handle data with varying time intervals, missing values, and time-based patterns, making them robust for real-world time series prediction tasks.
#
# ## ***Interpretation of Observations:***
#
# - The training process appears to be stable, with the loss decreasing consistently, indicating that the model is learning from the training data effectively.
#
# -  The model's performance metrics, MAE and RMSE, show that the model has a good predictive capability. However, the actual usefulness of these errors depends on the scale of the stock prices and the specific application or trading strategy where the model is used.
#
# - The model might benefit from further tuning, such as hyperparameter optimization, to potentially achieve even lower error rates.
#
# ## ***Insights:***
#
# - The LSTM model is capturing the trend of the stock prices well, as indicated by the plot. This suggests that it could be a valuable tool in a broader stock price prediction or trading system.
#
# - The relatively low MAE and RMSE values imply that the model could be used as a reliable forecast in a decision-making process, assuming the errors are within an acceptable range for the application.
#
# - Given the nature of stock prices, which are influenced by many unpredictable factors, the performance of the LSTM is quite promising. However, it's crucial to validate the model on out-of-sample data and consider other forms of analysis, such as fundamental and event-driven analysis, for a comprehensive stock evaluation strategy.
#
# - It's important to note that while the model performs well on the given dataset, the real test of its utility will be in how it performs in live or more recent conditions where the model hasn't seen the data during training.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
import matplotlib.pyplot as plt

class TunedLSTMTimeSeriesModel:
    def __init__(self, look_back=5, epochs=20, batch_size=20, lstm_units=50):
        self.look_back = look_back
        self.epochs = epochs
        self.batch_size = batch_size
        self.lstm_units = lstm_units
        self.model = None
        self.scaler = MinMaxScaler()

    def preprocess_data(self, data, date_column='Date'):
        data[date_column] = pd.to_datetime(data[date_column])
        data.set_index(date_column, inplace=True)
        
        # Normalize the data
        self.data_scaled = self.scaler.fit_transform(data)
        
        # Split the dataset into training and testing sets
        self.split_idx = int(len(self.data_scaled) * 0.8)
        self.train, self.test = self.data_scaled[:self.split_idx], self.data_scaled[self.split_idx:]
    
    def create_model(self, lstm_units=50):
        model = Sequential([
            LSTM(lstm_units, activation='relu', input_shape=(self.look_back, self.train.shape[1])),
            Dense(1)
        ])
        model.compile(optimizer='adam', loss='mean_squared_error')
        return model

    def tune_hyperparameters(self, param_grid):
        train_generator = TimeseriesGenerator(self.train, self.train, length=self.look_back, batch_size=self.batch_size)
        X, y = [], []
        for i in range(len(train_generator)):
            batch_x, batch_y = train_generator[i]
            X.extend(batch_x)
            y.extend(batch_y)
        X, y = np.array(X), np.array(y)
        
        model = KerasRegressor(build_fn=self.create_model, epochs=self.epochs, batch_size=self.batch_size, verbose=0)
        grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=3)
        grid_result = grid.fit(X, y)
        
        print(f"Best: {grid_result.best_score_} using {grid_result.best_params_}")
        self.model = grid_result.best_estimator_.model

    def train_model(self):
        train_generator = TimeseriesGenerator(self.train, self.train, length=self.look_back, batch_size=self.batch_size)
        input_shape = (self.look_back, self.train.shape[1])
        
        self.model = self.create_model(self.lstm_units)
        self.model.fit(train_generator, epochs=self.epochs, verbose=1)

    def predict(self):
        test_generator = TimeseriesGenerator(self.test, self.test, length=self.look_back, batch_size=1)
        predictions = self.model.predict(test_generator)
        predictions_inverted = self.scaler.inverse_transform(predictions)
        return predictions_inverted

    def visualize_and_evaluate(self, predictions, actual, start_idx=0):
        actual_aligned = actual[start_idx:]
        mae = mean_absolute_error(actual_aligned, predictions)
        rmse = np.sqrt(mean_squared_error(actual_aligned, predictions))

        plt.figure(figsize=(10, 6))
        plt.plot(actual_aligned, label='Actual', color='blue', marker='o')
        plt.plot(predictions, label='Predicted', color='red', linestyle='--', marker='x')
        plt.title('LSTM Time Series Prediction')
        plt.xlabel('Time')
        plt.ylabel('Value')
        plt.legend()
        plt.show()

        print(f"Mean Absolute Error (MAE): {mae:.4f}")
        print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")

# Example usage:
# Assuming `data` is your DataFrame and includes columns like 'Close' for stock prices.
data = m1data

# Hyperparameters grid
param_grid = {
    'lstm_units': [20, 50, 100],
    'batch_size': [16, 32, 64],
    'epochs': [10, 20, 30]
}

lstm_model = TunedLSTMTimeSeriesModel(look_back=5)
lstm_model.preprocess_data(data, date_column='Date')
lstm_model.tune_hyperparameters(param_grid)

# After hyperparameter tuning, you can train the model or directly make predictions if the model is already trained
lstm_model.train_model()
predictions = lstm_model.predict()

actual = lstm_model.scaler.inverse

#call visualize_and_evaluate on the lstm_model instance
lstm_model.visualize_and_evaluate(predictions, actual, start_idx=0)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3732\1828277793.py:46: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasRegressor(build_fn=self.create_model, epochs=self.epochs, batch_size=self.batch_size, verbose=0)
# Best: -0.00019693282229127362 using {'batch_size': 16, 'epochs': 30, 'lstm_units': 100}
# Epoch 1/20
# 198/198 [==============================] - 39s 34ms/step - loss: 0.0208
# Epoch 2/20
# 198/198 [==============================] - 5s 24ms/step - loss: 3.7947e-04
# Epoch 3/20
# 198/198 [==============================] - 3s 14ms/step - loss: 3.6899e-04
# Epoch 4/20
# 198/198 [==============================] - 3s 15ms/step - loss: 3.7400e-04
# Epoch 5/20
# 198/198 [==============================] - 4s 18ms/step - loss: 3.6216e-04
# Epoch 6/20
# 198/198 [==============================] - 4s 17ms/step - loss: 3.5099e-04
# Epoch 7/20
# 198/198 [==============================] - 3s 13ms/step - loss: 4.0770e-04
# Epoch 8/20
# 198/198 [==============================] - 3s 14ms/step - loss: 3.8343e-04
# Epoch 9/20
# 198/198 [==============================] - 3s 16ms/step - loss: 4.1785e-04
# Epoch 10/20
# 198/198 [==============================] - 5s 24ms/step - loss: 3.2930e-04
# Epoch 11/20
# 198/198 [==============================] - 4s 20ms/step - loss: 3.6000e-04
# Epoch 12/20
# 198/198 [==============================] - 4s 19ms/step - loss: 3.4765e-04
# Epoch 13/20
# 198/198 [==============================] - 7s 37ms/step - loss: 3.5607e-04
# Epoch 14/20
# 198/198 [==============================] - 6s 28ms/step - loss: 3.2166e-04
# Epoch 15/20
# 198/198 [==============================] - 6s 29ms/step - loss: 3.3611e-04
# Epoch 16/20
# 198/198 [==============================] - 5s 23ms/step - loss: 3.9272e-04
# Epoch 17/20
# 198/198 [==============================] - 10s 49ms/step - loss: 3.1124e-04
# Epoch 18/20
# 198/198 [==============================] - 4s 21ms/step - loss: 3.0742e-04
# Epoch 19/20
# 198/198 [==============================] - 6s 30ms/step - loss: 3.2145e-04
# Epoch 20/20
# 198/198 [==============================] - 3s 17ms/step - loss: 3.1105e-04
# 986/986 [==============================] - 29s 19ms/step
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 102
#      99 lstm_model.train_model()
#     100 predictions = lstm_model.predict()
# --> 102 actual = lstm_model.scaler.inverse
#     104 #call visualize_and_evaluate on the lstm_model instance
#     105 lstm_model.visualize_and_evaluate(predictions, actual, start_idx=0)
#
# AttributeError: 'MinMaxScaler' object has no attribute 'inverse'
